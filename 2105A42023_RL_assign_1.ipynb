# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhil42023/AI-ML/blob/main/2105A42023_RL_assign_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Part 1 - Implement Basic Data Structures using Numpy, Pandas
# 1. Lists
list1 = [3, 6, 8, 9, 7]
l = pd.Series(list1)
# 2. Arrays
array1 = np.array([1, 5, 7, 4, 5])
# 3. Identify their type using type()
print("Type of list1:", l)
print("Type of array1:", array1)
# 4. Perform mathematical operations
print("Multiplication:", array1 * 2)
print("Division:", array1 / 2)
print("Power of:", array1 ** 2)
# 5. Combine text with Numpy function
print("Addition of Two:", np.add(array1, array1))
# 6. Implement np.sin(), log(), log2(), np.exp()
print("Sin:", np.sin(array1))
print("Log:", np.log(array1))
print("Log2:", np.log2(array1))
print("Exp:", np.exp(array1))
# Out:
# Type of list1: 0    3
# 1    6
# 2    8
# 3    9
# 4    7
# dtype: int64
# Type of array1: [1 5 7 4 5]
# Multiplication: [ 2 10 14  8 10]
# Division: [0.5 2.5 3.5 2.  2.5]
# Power of: [ 1 25 49 16 25]
# Addition of Two: [ 2 10 14  8 10]
# Sin: [ 0.84147098 -0.95892427  0.6569866  -0.7568025  -0.95892427]
# Log: [0.         1.60943791 1.94591015 1.38629436 1.60943791]
# Log2: [0.         2.32192809 2.80735492 2.         2.32192809]
# Exp: [   2.71828183  148.4131591  1096.63315843   54.59815003  148.4131591 ]

# %%
people = ['NIKHIL', 'REDDY', 'AJAY', 'CHINNU']
age = [20, 32, 55, 40]
height = [145, 161, 169, 173]
weight = [70, 55, 65, 75]

# Scatter Plot
plt.scatter(age, height)
plt.title('Age vs Height')
plt.xlabel('Age')
plt.ylabel('Height')
plt.show()

# Bar Chart
plt.bar(people, weight)
plt.title('Weight of People')
plt.xlabel('People')
plt.ylabel('Weight')
plt.show()

# Histogram
plt.hist(age, bins=3)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# !pip install openpyxl

# %%
import numpy as np
import pandas as pd
from google.colab import files
df = pd.read_excel('/content/Gold prices (18.08.2023 - 22.01.2024).xlsx')
df
# Out:
#            Date Close/Last   Volume      Open      High       Low
# 0    01/22/2024   2,022.20  141.963  2,031.80  2,034.10  2,017.40
# 1    01/19/2024   2,029.30  166.078  2,027.40  2,041.90  2,022.20
# 2    01/18/2024   2,021.60  167.013  2,009.10  2,025.60  2,007.70
# 3    01/17/2024   2,006.50  245.194  2,031.70  2,036.10  2,004.60
# 4    01/16/2024   2,030.20  277.995  2,053.40  2,062.80  2,027.60
# ..          ...        ...      ...       ...       ...       ...
# 102  08/24/2023   1,947.10  133.727  1,944.90  1,951.30  1,939.20
# 103  08/23/2023   1,948.10  162.315  1,926.80  1,949.70  1,926.20
# 104  08/22/2023   1,926.00  126.226  1,924.00  1,933.20  1,917.50
# 105  08/21/2023   1,923.00  135.415  1,918.40  1,927.90  1,913.60
# 106  08/18/2023   1,916.50  110.337  1,919.20  1,926.00  1,915.90
#
# [107 rows x 6 columns]

# %%
df.to_csv('Gold prices (18.08.2023 - 22.01.2024).tsv', sep='\t', index=False)
df = pd.read_csv("Gold prices (18.08.2023 - 22.01.2024).tsv",sep='\t')
df
# Out:
#            Date Close/Last   Volume      Open      High       Low
# 0    01/22/2024   2,022.20  141.963  2,031.80  2,034.10  2,017.40
# 1    01/19/2024   2,029.30  166.078  2,027.40  2,041.90  2,022.20
# 2    01/18/2024   2,021.60  167.013  2,009.10  2,025.60  2,007.70
# 3    01/17/2024   2,006.50  245.194  2,031.70  2,036.10  2,004.60
# 4    01/16/2024   2,030.20  277.995  2,053.40  2,062.80  2,027.60
# ..          ...        ...      ...       ...       ...       ...
# 102  08/24/2023   1,947.10  133.727  1,944.90  1,951.30  1,939.20
# 103  08/23/2023   1,948.10  162.315  1,926.80  1,949.70  1,926.20
# 104  08/22/2023   1,926.00  126.226  1,924.00  1,933.20  1,917.50
# 105  08/21/2023   1,923.00  135.415  1,918.40  1,927.90  1,913.60
# 106  08/18/2023   1,916.50  110.337  1,919.20  1,926.00  1,915.90
#
# [107 rows x 6 columns]

# %%
df.to_csv('Gold prices (18.08.2023 - 22.01.2024).csv', index=False)
df = pd.read_csv('Gold prices (18.08.2023 - 22.01.2024).csv')
df
# Out:
#            Date Close/Last   Volume      Open      High       Low
# 0    01/22/2024   2,022.20  141.963  2,031.80  2,034.10  2,017.40
# 1    01/19/2024   2,029.30  166.078  2,027.40  2,041.90  2,022.20
# 2    01/18/2024   2,021.60  167.013  2,009.10  2,025.60  2,007.70
# 3    01/17/2024   2,006.50  245.194  2,031.70  2,036.10  2,004.60
# 4    01/16/2024   2,030.20  277.995  2,053.40  2,062.80  2,027.60
# ..          ...        ...      ...       ...       ...       ...
# 102  08/24/2023   1,947.10  133.727  1,944.90  1,951.30  1,939.20
# 103  08/23/2023   1,948.10  162.315  1,926.80  1,949.70  1,926.20
# 104  08/22/2023   1,926.00  126.226  1,924.00  1,933.20  1,917.50
# 105  08/21/2023   1,923.00  135.415  1,918.40  1,927.90  1,913.60
# 106  08/18/2023   1,916.50  110.337  1,919.20  1,926.00  1,915.90
#
# [107 rows x 6 columns]

# %%
import requests

# URL of the text file
url = "https://www.bing.com/search?pglt=41&q=google&cvid=6b1c7f071c994476b853376238b51ecc&gs_lcrp=EgZjaHJvbWUqBggAEAAYQDIGCAAQABhAMgYIARBFGDkyBggCEAAYQDIGCAMQLhhAMgYIBBAuGEAyBggFEEUYPDIGCAYQRRg8MgYIBxBFGDwyBggIEEUYPNIBCDIyNTNqMGoxqAIAsAIA&FORM=ANSPA1&PC=HCTS"

# Fetch the content from the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Extract the text content
    text_content = response.text

    # Display the text content
    print("Text from URL:")
    print(text_content)
else:
    print("Failed to fetch data from the URL.")
# Out:
# Text from URL:
# <!DOCTYPE html><html dir="ltr" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:Web="http://schemas.live.com/Web/"><script type="text/javascript" >//<![CDATA[
# si_ST=new Date
# ...
